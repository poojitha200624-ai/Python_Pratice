# %%
a = int(input())
b = int(input())
print(a + b)
# Out:
# 156

# %%
a = int(input())
b = int(input())
print(a - b)
# Out:
# 53

# %%
a = int(input())
b = int(input())
print(a * b)
# Out:
# 45

# %%
a = int(input())
b = int(input())
print(a // b)
# Out:
# 8

# %%
a = int(input())
b = int(input())
print(a % b)
# Out:
# 1

# %%
a = int(input())
b = int(input())
temp = a
a = b
b = temp
print(a, b)
# Out:
# 34 56

# %%
a = int(input())
b = int(input())
a = a + b
b = a - b
a = a - b
print(a, b)
# Out:
# 32 45

# %%
n = int(input())
print(n % 10)
# Out:
# 7

# %%
n = int(input())
print(n // 10)
# Out:
# 6

# %%
n = int(input())
first = n // 100
last = n % 10
print(first + last)
# Out:
# 8

# %%
n = int(input())
middle = (n // 10) % 10
print(middle)
# Out:
# 5

# %%
n = int(input())
print(n * n)
# Out:
# 36

# %%
n = int(input())
print(n * n * n)
# Out:
# 64

# %%
a = int(input())
b = int(input())
c = int(input())
print((a + b + c) / 3)
# Out:
# 3.6666666666666665

# %%
a = int(input())
b = int(input())
print(a == b)
# Out:
# True

# %%
n = int(input())
print((n > 0) and ((n & (n - 1)) == 0))
# Out:
# False

# %%
n = int(input())
if n >= 0:
    print("Positive")
else:
    print("Negative")
# Out:
# Negative

# %%
a = int(input())
b = int(input())
c = int(input())
print(max(a, b, c))
# Out:
# 6

# %%
marks = int(input())
if marks >= 35:
    print("Pass")
else:
    print("Fail")
# Out:
# Pass
