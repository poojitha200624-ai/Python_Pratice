# %%
print("Welcome")
# Out:
# Welcome

# %%
word = input()
print(word)
# Out:
# hi

# %%
message = input()
print(message)
# Out:
# hello

# %%
num = int(input())
print(num)
# Out:
# 67

# %%
num = float(input())
print(num)
# Out:
# 78.0

# %%
num = float(input())
print("{:.2f}".format(num))
# Out:
# 56.90

# %%
num = int(input())
print(hex(num))
# Out:
# 0x7

# %%
num = int(input())
print(oct(num))
# Out:
# 0o6

# %%
hex_num = input()
print(int(hex_num, 16))
# Out:
# 18

# %%
oct_num = input()
print(int(oct_num, 8))
# Out:
# 53

# %%
num = int(input())
print(chr(num))
# Out:
# N

# %%
a = int(input())
b = int(input())
print(a, b)
# Out:
# 8 9

# %%
a = int(input())
b = int(input())
print(a, b, sep="\t")
# Out:
# 78	98

# %%
a = int(input())
b = int(input())
print(a)
print(b)
# Out:
# 78
# 54

# %%
ch = input()
print("'" + ch + "'")
# Out:
# 'hu'

# %%
word1 = input()
word2 = input()
print('"' + word1 + '" "' + word2 + '"')
# Out:
# "hello" "hk"

# %%
day = input()
month = input()
year = input()
print(day + "/" + month + "/" + year)

# %%
num = int(input())
print("{:+d}".format(num))
# Out:
# +5

# %%
num = int(input())
print("{:+d}".format(num))
# Out:
# +89

# %%
import sys
print("char:", 1)
print("int:", sys.getsizeof(int()))
print("float:", sys.getsizeof(float()))
print("double:", sys.getsizeof(float()))
# Out:
# char: 1
# int: 24
# float: 24
# double: 24

# %%
for i in range(5):
    mark = input()
    print(mark)
# Out:
# 45
# 90
# 25
# 87
# 100

# %%
blood_group = input()
print(blood_group)
# Out:
# o+

# %%
from datetime import datetime
print(datetime.now().strftime("%H:%M:%S"))
# Out:
# 10:00:01

# %%
print("123, ABC Street\nXYZ Nagar\nChennai\nIndia")
# Out:
# 123, ABC Street
# XYZ Nagar
# Chennai
# India
